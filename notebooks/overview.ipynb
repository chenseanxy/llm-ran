# %%
import pandas as pd
from plotnine import (
    ggplot, geom_point, geom_line, geom_smooth, geom_bar,
    aes, facet_wrap, labs,
    scale_x_log10, scale_y_continuous, scale_y_log10,
    theme_grey, theme, theme_matplotlib,
)
import plotnine as pn
import patchworklib as pw
import numpy as np
from llm_ran.benchmark.metrics import pass_at, pass_power
from llm_ran.benchmark.questions import TEST_CASES

my_theme = lambda x, y: pn.theme_classic() + pn.theme(
    axis_text_x=pn.element_text(rotation=15, hjust=1),
    panel_grid_major_y=pn.element_line(size=0.5, color="grey"),
    panel_border=pn.element_rect(size=1, color="black"),
    figure_size=(x, y)
)

# %%
QUESTIONS_META = {
    (test_case.scenario, question.id): question
    for test_case in TEST_CASES
    for question in test_case.questions
}

levels = ["Simple Fact Finding", "Complex Fact Finding", "Reasoning"]

questions = pd.DataFrame([
    {
        "scenario": test_case.scenario or "base",
        "question": question.id,
        "question_type": levels[question.level],
    }
    for test_case in TEST_CASES
    for question in test_case.questions
]).set_index(["scenario", "question"])
display(len(questions))
# Out:
# 43

# %%
DATA_PATH = "../data"
OUTPUT_PATH = "../../thesis/figures"

mainline_models = [
    "mixtral:8x22b",
    "sky-t1:32b",
    "qwen2.5:32b",
    "qwen2.5-coder:32b",
    "qwq:32b",
]

df = pd.read_csv(f"{DATA_PATH}/processed/combined.csv", index_col=0)
df = df[df['model'].isin(mainline_models)]
df = df.rename(columns={"chain": "agent"})
df = df.join(questions, on=["scenario", "question"])
df['question_type'] = pd.Categorical(df['question_type'], categories=levels, ordered=True)
df['model'] = pd.Categorical(df['model'], categories=mainline_models, ordered=True)

zero_to_na = ["total_tokens"]
for col in zero_to_na:
    df[col] = df[col].replace(0, np.nan)

df.columns
# Out:
# Index(['scenario', 'question', 'trial', 'run_id', 'model', 'agent',
#        'total_trials', 'level', 'evaluate_as', 'expected', 'num_messages',
#        'execution_time', 'eval_count', 'prompt_eval_count', 'eval_duration',
#        'prompt_eval_duration', 'load_duration', 'total_duration',
#        'total_tokens', 'max_eval_count', 'max_prompt_eval_count',
#        'max_eval_duration', 'max_prompt_eval_duration', 'max_load_duration',
#        'max_total_duration', 'snapshot_path', 'result', 'error', 'file',
#        'can_answer', 'correct', 'pass', 'deviation', 'question_type'],
#       dtype='object')

# %%
group_by = ["model", "agent"]
metrics = ["can_answer", "correct", 'execution_time', "total_tokens", "num_messages", "pass"]

agg1 = {
    "can_answer@5": ('can_answer', pass_at(5)),
    "can_answer@1": ('can_answer', pass_at(1)),
    "can_answer^5": ('can_answer', pass_power(5)),
    "can_answer@10": ('can_answer', pass_at(10)),
    "can_answer^10": ('can_answer', pass_power(10)),
    "correct@5": ('correct', pass_at(5)),
    "correct@1": ('correct', pass_at(1)),
    "correct^5": ('correct', pass_power(5)),
    "correct@10": ('correct', pass_at(10)),
    "correct^10": ('correct', pass_power(10)),
    "pass@5": ('pass', pass_at(5)),
    "pass@1": ('pass', pass_at(1)),
    "pass^5": ('pass', pass_power(5)),
    "pass@10": ('pass', pass_at(10)),
    "pass^10": ('pass', pass_power(10)),
    "execution_time": ('execution_time', 'mean'),
    "total_tokens": ('total_tokens', 'mean'),
    "num_messages": ('num_messages', 'mean'),
}
groupby1 = ["scenario", "question"]

raw = df.groupby(group_by + groupby1)[metrics].agg(**agg1).reset_index()
display(raw)
raw_pivoted = raw.melt(
    id_vars=group_by,
    value_vars=[*agg1.keys()],
    var_name="metric",
    value_name="value",
)
raw_grouped = raw_pivoted.groupby(
    group_by + ["metric"]
).agg(
    value_min=('value', 'min'),
    value_max=('value', 'max'),
    value=('value', lambda x: x.quantile(0.5)),
    value_25=('value', lambda x: x.quantile(0.25)),
    # value_50=('value', lambda x: x.quantile(0.5)),
    value_75=('value', lambda x: x.quantile(0.75)),
).reset_index()
display(raw_grouped)

# resampled = df.groupby(group_by + groupby1)[metrics].agg(**agg1).reset_index().groupby(group_by)[list(agg1.keys())].agg('mean').join(
#     df.groupby(group_by)[list(agg.keys())].agg('mean'), on=group_by
# ).reset_index()
# # resampled = df.groupby(group_by)[metrics].agg(**agg).reset_index()
# # display(resampled)
# pivoted = resampled.melt(
#     id_vars=group_by,
#     value_vars=[*agg.keys(), *agg1.keys()],
#     var_name="metric",
#     value_name="value",
# )
# # display(pivoted)
# Out:
#               model    agent             scenario  \
# 0     mixtral:8x22b  codegen                 base
# 1     mixtral:8x22b  codegen                 base
# 2     mixtral:8x22b  codegen                 base
# 3     mixtral:8x22b  codegen                 base
# 4     mixtral:8x22b  codegen                 base
# ...             ...      ...                  ...
# 1345        qwq:32b   direct  resource-constraint
# 1346        qwq:32b   direct  resource-constraint
# 1347        qwq:32b   direct  resource-constraint
# 1348        qwq:32b   direct  resource-constraint
# 1349        qwq:32b   direct  resource-constraint
#
#                                      question  can_answer@5  can_answer@1  \
# 0                              how-many-nodes           0.0           0.0
# 1        how-many-nodes-does-a-deployment-use           0.0           0.0
# 2                how-many-pods-for-deployment           0.0           0.0
# 3        how-many-pods-for-deployment-pending           NaN           NaN
# 4      how-many-pods-for-deployment-unhealthy           NaN           NaN
# ...                                       ...           ...           ...
# 1345                why-is-deployment-failing           1.0           1.0
# 1346  why-is-deployment-not-receiving-traffic           NaN           NaN
# 1347        why-is-deployment-not-rolling-out           1.0           1.0
# 1348                       why-is-pod-pending           1.0           1.0
# 1349                     why-is-pod-unhealthy           NaN           NaN
#
#       can_answer^5  can_answer@10  can_answer^10  correct@5  ...  correct@10  \
# 0              0.0            0.0            0.0   0.600877  ...    0.894737
# 1              0.0            0.0            0.0   0.806308  ...    0.983746
# 2              0.0            0.0            0.0   0.870872  ...    0.994582
# 3              NaN            NaN            NaN        NaN  ...         NaN
# 4              NaN            NaN            NaN        NaN  ...         NaN
# ...            ...            ...            ...        ...  ...         ...
# 1345           1.0            1.0            1.0   1.000000  ...    1.000000
# 1346           NaN            NaN            NaN        NaN  ...         NaN
# 1347           1.0            1.0            1.0   1.000000  ...    1.000000
# 1348           1.0            1.0            1.0   1.000000  ...    1.000000
# 1349           NaN            NaN            NaN        NaN  ...         NaN
#
#         correct^10  pass@5  pass@1   pass^5  pass@10   pass^10  \
# 0     5.766504e-09     0.0     0.0  0.00000      0.0  0.000000
# 1     9.536743e-07     0.0     0.0  0.00000      0.0  0.000000
# 2     5.904900e-06     0.0     0.0  0.00000      0.0  0.000000
# 3              NaN     NaN     NaN      NaN      NaN       NaN
# 4              NaN     NaN     NaN      NaN      NaN       NaN
# ...            ...     ...     ...      ...      ...       ...
# 1345  1.000000e+00     1.0     1.0  1.00000      1.0  1.000000
# 1346           NaN     NaN     NaN      NaN      NaN       NaN
# 1347  2.824752e-02     1.0     0.7  0.16807      1.0  0.028248
# 1348  1.000000e+00     1.0     1.0  1.00000      1.0  1.000000
# 1349           NaN     NaN     NaN      NaN      NaN       NaN
#
#       execution_time  total_tokens  num_messages
# 0           5.051345        498.25          2.85
# 1          11.724542       1338.75          3.20
# 2           6.877947        656.15          3.00
# 3                NaN           NaN           NaN
# 4                NaN           NaN           NaN
# ...              ...           ...           ...
# 1345       40.201936       7581.60          7.10
# 1346             NaN           NaN           NaN
# 1347       39.976717       6520.80          6.10
# 1348       22.210251       4181.70          4.40
# 1349             NaN           NaN           NaN
#
# [1350 rows x 22 columns]
#              model    agent         metric  value_min     value_max  \
# 0    mixtral:8x22b  codegen   can_answer@1        0.0  5.000000e-02
# 1    mixtral:8x22b  codegen  can_answer@10        0.0  5.000000e-01
# 2    mixtral:8x22b  codegen   can_answer@5        0.0  2.500000e-01
# 3    mixtral:8x22b  codegen  can_answer^10        0.0  9.765625e-14
# 4    mixtral:8x22b  codegen   can_answer^5        0.0  3.125000e-07
# ..             ...      ...            ...        ...           ...
# 175        qwq:32b   direct        pass@10        0.0  1.000000e+00
# 176        qwq:32b   direct         pass@5        0.0  1.000000e+00
# 177        qwq:32b   direct        pass^10        0.0  1.000000e+00
# 178        qwq:32b   direct         pass^5        0.0  1.000000e+00
# 179        qwq:32b   direct   total_tokens     2001.7  1.697250e+04
#
#            value     value_25     value_75
# 0       0.000000     0.000000     0.000000
# 1       0.000000     0.000000     0.000000
# 2       0.000000     0.000000     0.000000
# 3       0.000000     0.000000     0.000000
# 4       0.000000     0.000000     0.000000
# ..           ...          ...          ...
# 175     1.000000     1.000000     1.000000
# 176     1.000000     0.990067     1.000000
# 177     0.196874     0.003512     1.000000
# 178     0.443705     0.054505     1.000000
# 179  5643.600000  3909.750000  8277.504167
#
# [180 rows x 8 columns]

# %%
def draw_metrics(data, metrics, ylabel, x='model', xlabel='Model', width=12, height=3, color='metric', logy=False):
    _data = data[data['metric'].isin(metrics)].copy()
    _data["metric"] = pd.Categorical(_data["metric"], categories=metrics, ordered=True)

    p = (
        ggplot(_data)
        + pn.geom_boxplot(
            aes(
                x=x,
                ymin="value_min",
                lower="value_25",
                middle="value",
                upper="value_75",
                ymax="value_max",
                color=color
            ),
            position="dodge2", stat = "identity",
        )
        + facet_wrap("~agent", labeller="label_both")
        + labs(
            x=xlabel,
            y=ylabel,
            fill="metric",
        )
        + my_theme(width, height)
    )
    if logy:
        p += scale_y_log10()
    return p

# %%
_pass_metrics = [
    "pass@10",
    "pass@5",
    "pass@1",
    "pass^5",
    "pass^10",
]
_can_answer_metrics = [
    "can_answer@10",
    "can_answer@5",
    "can_answer@1",
    "can_answer^5",
    "can_answer^10",
]
_correct_metrics = [
    "correct@10",
    "correct@5",
    "correct@1",
    "correct^5",
    "correct^10",
]
_g11 = draw_metrics(raw_grouped, _pass_metrics, "Pass Rate (0-1)")
_g1 = draw_metrics(raw_grouped, _can_answer_metrics, ylabel="Can Answer Rate (0-1)")
_g2 = draw_metrics(raw_grouped, _correct_metrics, ylabel="Correct Rate (0-1)")
display(_g11)
display(_g1)
display(_g2)
_g11.save(f"{OUTPUT_PATH}/overview_pass.pdf", bbox_inches="tight", dpi=300, pad_inches=0)
_g1.save(f"{OUTPUT_PATH}/overview_can_answer.pdf", bbox_inches="tight", dpi=300, pad_inches=0)
_g2.save(f"{OUTPUT_PATH}/overview_correct.pdf", bbox_inches="tight", dpi=300, pad_inches=0)
# _g = pw.load_ggplot(_g1) / pw.load_ggplot(_g2)
# _g.savefig(f"{OUTPUT_PATH}/overview_performance_breakdown.png", bbox_inches="tight")
# Out:
# <Figure Size: (1200 x 300)>
# <Figure Size: (1200 x 300)>
# <Figure Size: (1200 x 300)>

# %%
_cost_groupby = group_by + ['correct']
cost = df.melt(
    id_vars=_cost_groupby,
    value_vars=["execution_time", "total_tokens", "num_messages"],
    var_name="metric",
    value_name="value",
).groupby(
    _cost_groupby + ["metric"]
).agg(
    value_min=('value', 'min'),
    value_max=('value', 'max'),
    value=('value', lambda x: x.quantile(0.5)),
    value_25=('value', lambda x: x.quantile(0.25)),
    # value_50=('value', lambda x: x.quantile(0.5)),
    value_75=('value', lambda x: x.quantile(0.75)),
).reset_index()

_g1 = draw_metrics(cost, ["execution_time"], ylabel="Execution Time (s)", x='model', xlabel='Model', logy=True, width=12, height=3, color='correct')
_g2 = draw_metrics(cost, ["total_tokens"], ylabel="Total Tokens", x='model', xlabel='Model', logy=True, width=12, height=3, color='correct')
_g3 = draw_metrics(cost, ["num_messages"], ylabel="Number of Messages", x='model', xlabel='Model', logy=True, width=12, height=3, color='correct')
display(_g1)
display(_g2)
display(_g3)
_g1.draw().savefig(f"{OUTPUT_PATH}/overview_execution_time.pdf", bbox_inches="tight", pad_inches=0)
_g2.draw().savefig(f"{OUTPUT_PATH}/overview_total_tokens.pdf", bbox_inches="tight", pad_inches=0)
_g3.draw().savefig(f"{OUTPUT_PATH}/overview_num_messages.pdf", bbox_inches="tight", pad_inches=0)
# Out:
# <Figure Size: (1200 x 300)>
# <Figure Size: (1200 x 300)>
# <Figure Size: (1200 x 300)>

# %%
(df['max_prompt_eval_count'] > 31000).mean() * 100
# Out:
# 0.01639344262295082

# %%
(df['error'] == "ReadTimeout").mean() * 100
# Out:
# 1.1639344262295082

# %%
(df['error'] == "GraphRecursionError").mean() * 100
# Out:
# 0.11475409836065574
